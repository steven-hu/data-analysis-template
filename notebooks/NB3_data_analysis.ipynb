# %% [markdown]
# In this notebook, you'll perform the actual analysis of the data stored in the directory
#
#     ./data/cleaned
#
# If the data is not ready yet (e.g. the other members of the team in charge of cleaning the data are not done yet), you may want to simulate cleaned data in the form you want them to be in order to perform the analysis. This may also help you data cleaning team to come up with the rigth data frame.
# If you choose to do so, store your simulated data into the directory
#
#     ./data/simulated
#
# Having performed analysis of simulated data may help you with the analysis of the actual data, since you will be able to notice deviations between the real and simulated data, which may be worth explaining and investigating further.
#
# The graphics your going to produce as a result of your analysis should be store in the directory:
#
#
#     ./visualization

# %% [markdown]
# ##Team members responsible for this notebook:
#
# List the team members contributing to this notebook, along with their responsabilities:
#
# * team member 1 **name**: team member 1 **responsabilities**
# * team member 2 **name**: team member 2 **responsabilities**
# * etc.
#
# I advise you to work at least in pairs for each project notebook, as you did for the homework assignments. Of course, all team members may participate to each notebook.

# %%
# %load_ext rmagic

# %%
# %%R
# ATL=read.csv("~/sun-and-shield-project/data/cleaned/ATL.csv",header=FALSE)
# BOS=read.csv("~/sun-and-shield-project/data/cleaned/BOS.csv",header=FALSE)
# CLT=read.csv("~/sun-and-shield-project/data/cleaned/CLT.csv",header=FALSE)
# DEN=read.csv("~/sun-and-shield-project/data/cleaned/DEN.csv",header=FALSE)
# DFW=read.csv("~/sun-and-shield-project/data/cleaned/DFW.csv",header=FALSE)
# DTW=read.csv("~/sun-and-shield-project/data/cleaned/DTW.csv",header=FALSE)
# EWR=read.csv("~/sun-and-shield-project/data/cleaned/EWR.csv",header=FALSE)
# IAH=read.csv("~/sun-and-shield-project/data/cleaned/IAH.csv",header=FALSE)
# LAS=read.csv("~/sun-and-shield-project/data/cleaned/LAS.csv",header=FALSE)
# LAX=read.csv("~/sun-and-shield-project/data/cleaned/LAX.csv",header=FALSE)
# LGA=read.csv("~/sun-and-shield-project/data/cleaned/LGA.csv",header=FALSE)
# MSP=read.csv("~/sun-and-shield-project/data/cleaned/MSP.csv",header=FALSE)
# ORD=read.csv("~/sun-and-shield-project/data/cleaned/ORD.csv",header=FALSE)
# PHL=read.csv("~/sun-and-shield-project/data/cleaned/PHL.csv",header=FALSE)
# PHX=read.csv("~/sun-and-shield-project/data/cleaned/PHX.csv",header=FALSE)
# PIT=read.csv("~/sun-and-shield-project/data/cleaned/PIT.csv",header=FALSE)
# SEA=read.csv("~/sun-and-shield-project/data/cleaned/SEA.csv",header=FALSE)
# SFO=read.csv("~/sun-and-shield-project/data/cleaned/SFO.csv",header=FALSE)
# SLC=read.csv("~/sun-and-shield-project/data/cleaned/SLC.csv",header=FALSE)
# STL=read.csv("~/sun-and-shield-project/data/cleaned/STL.csv",header=FALSE)

# %%
# %%R
# airports=rbind(ATL,BOS,CLT,DEN,DFW,DTW,EWR,IAH,LAS,LAX,LGA,MSP,ORD,PHL,PHX,PIT,SEA,SFO,SLC,STL)

# %%
# %%R
# delay=c(airports$V4)
# origin=c(as.character(airports$V1))
# data=data.frame(delay=delay,origin=origin)

# %%
# %%R
# print(tapply(data$delay,data$origin,summary))
# Out:
# $ATL
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    1.00   11.27   10.00  500.00
#
# $BOS
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0     0.0     0.0    10.6     7.0   500.0
#
# $CLT
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.000   0.000   1.000   9.753   9.000 500.000
#
# $DEN
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    0.00   10.28    8.00  498.00
#
# $DFW
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0     0.0     0.0    10.2     8.0   499.0
#
# $DTW
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    0.00   10.11    7.00  500.00
#
# $EWR
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0     0.0     0.0    12.5     9.0   500.0
#
# $IAH
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    0.00    8.64    5.00  500.00
#
# $LAS
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    0.00   10.02    9.00  499.00
#
# $LAX
# ...

# %%
# %%R
# avgs=tapply(data$delay,data$origin,mean)
# print(avgs)
# Out:
#       ATL       BOS       CLT       DEN       DFW       DTW       EWR       IAH
# 11.270744 10.601876  9.752695 10.276824 10.202021 10.112165 12.504361  8.639502
#       LAS       LAX       LGA       MSP       ORD       PHL       PHX       PIT
# 10.016496  9.064853  9.916390  8.880639 12.919656 11.849546  9.702281  9.381067
#       SEA       SFO       SLC       STL
#  9.485587 10.903367  7.865211  9.216288

# %%
# %%R
# ddiff=avgs-mean(data$delay)
# print(ddiff)
# Out:
#         ATL         BOS         CLT         DEN         DFW         DTW
#  0.92261949  0.25375152 -0.59542949 -0.07130053 -0.14610366 -0.23596012
#         EWR         IAH         LAS         LAX         LGA         MSP
#  2.15623656 -1.70862292 -0.33162901 -1.28327165 -0.43173523 -1.46748571
#         ORD         PHL         PHX         PIT         SEA         SFO
#  2.57153065  1.50142147 -0.64584423 -0.96705827 -0.86253828  0.55524184
#         SLC         STL
# -2.48291369 -1.13183714

# %%
# %%R
# plot(unique(data$origin),avgs,main="Average Delay Times by Airport",xlab="Airport",ylab="Average delay times (min)")

# %%
# %%R
# hist(avgs,xlab="Average delay times (min)",main="Histogram of Average Delay Times")

# %%
# %%R
# carriers=unique(data$origin)
# prop={}
# for(i in 1:20){
#     airport=data$delay[data$origin == carriers[i]]
#     total=length(airport)
#     del=length(airport[airport != 0])
#     prop=c(prop,del/total)
#     }
# table=data.frame(carriers=carriers, prop=prop)
# print(table)
# Out:
#    carriers      prop
# 1       ATL 0.5295946
# 2       BOS 0.4195840
# 3       CLT 0.5165910
# 4       DEN 0.4626000
# 5       DFW 0.4965155
# 6       DTW 0.4151824
# 7       EWR 0.4359185
# 8       IAH 0.4093387
# 9       LAS 0.4269760
# 10      LAX 0.4418887
# 11      LGA 0.4081828
# 12      MSP 0.3720727
# 13      ORD 0.5053018
# 14      PHL 0.4994521
# 15      PHX 0.4338250
# 16      PIT 0.5197303
# 17      SEA 0.4156508
# 18      SFO 0.4516042
# 19      SLC 0.4249509
# 20      STL 0.3957319

# %%
# %%R
# plot(table$carriers,table$prop,main="Proportion of Flights Delayed by Airport",xlab="Airport",ylab="Proportion delayed")

# %%
# %%R
# d=data
# d[d==0]=NA
# avgs2=tapply(d$delay,d$origin,mean,na.rm=TRUE)
# print(avgs2)
# Out:
#      ATL      BOS      CLT      DEN      DFW      DTW      EWR      IAH
# 21.28183 25.26759 18.87895 22.21536 20.54723 24.35596 28.68509 21.10600
#      LAS      LAX      LGA      MSP      ORD      PHL      PHX      PIT
# 23.45915 20.51388 24.29399 23.86802 25.56819 23.72509 22.36450 18.04987
#      SEA      SFO      SLC      STL
# 22.82105 24.14363 18.50852 23.28922

# %%
# %%R
# plot(unique(data$origin),avgs2,main="Average Delay Times by Airport",xlab="Airport",ylab="Average delay times (min)")

# %%
# %%R
# par(mfrow=c(1,3))
# plot(unique(data$origin),avgs,main="Average Delay Times by Airport",xlab="Airport",ylab="Average delay times (min)")
# plot(unique(data$origin),avgs2,main="Average Delay Times by Airport",xlab="Airport",ylab="Average delay times (min)")
# plot(table$carriers,table$prop,main="Proportion of Flights Delayed by Airport",xlab="Airport",ylab="Proportion delayed")

# %%
# %%R
# print(tapply(data$delay,data$origin,t.test))
# Out:
# $ATL
#
# 	One Sample t-test
#
# data:  X[[1L]]
# t = 1039.495, df = 5993194, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  11.24949 11.29200
# sample estimates:
# mean of x
#  11.27074
#
#
# $BOS
#
# 	One Sample t-test
#
# data:  X[[2L]]
# t = 546.0485, df = 2211649, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  10.56382 10.63993
# sample estimates:
# mean of x
#  10.60188
#
#
# $CLT
#
# 	One Sample t-test
#
# data:  X[[3L]]
# t = 664.5366, df = 2501837, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  9.723931 9.781460
# sample estimates:
# mean of x
#  9.752695
#
#
# $DEN
#
# 	One Sample t-test
#
# data:  X[[4L]]
# t = 708.5052, df = 3273103, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  10.24840 10.30525
# sample estimates:
# mean of x
# ...

# %%
# %%R
# print(anova(lm(delay~origin,data)))
# Out:
# Error: cannot allocate vector of size 479.0 Mb

# %%
# %%R
# print(TukeyHSD(aov(delay~origin,data)))
# Out:
# Error: cannot allocate vector of size 479.0 Mb

# %%
# %%R
# print(anova(lm(delay~airlines,data)))
# Out:
# Analysis of Variance Table
#
# Response: delay
#                 Df     Sum Sq Mean Sq F value    Pr(>F)
# airlines         4 5.6244e+06 1406088    2074 < 2.2e-16 ***
# Residuals 19585816 1.3278e+10     678
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
# %%R
# print(anova(lm(delay~origin,d,na.rm=TRUE)))
# Out:
# $ATL
#
# 	One Sample t-test
#
# data:  X[[1L]]
# t = 1039.495, df = 5993194, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  11.24949 11.29200
# sample estimates:
# mean of x
#  11.27074
#
#
# $BOS
#
# 	One Sample t-test
#
# data:  X[[2L]]
# t = 546.0485, df = 2211649, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  10.56382 10.63993
# sample estimates:
# mean of x
#  10.60188
#
#
# $CLT
#
# 	One Sample t-test
#
# data:  X[[3L]]
# t = 664.5366, df = 2501837, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  9.723931 9.781460
# sample estimates:
# mean of x
#  9.752695
#
#
# $DEN
#
# 	One Sample t-test
#
# data:  X[[4L]]
# t = 708.5052, df = 3273103, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  10.24840 10.30525
# sample estimates:
# mean of x
# ...

# %%
# %%R
# print(tapply(d$delay,d$airlines,mean,na.rm=TRUE))d

# %%
# %%R
# print(TukeyHSD(aov(delay~origin,d,na.rm=TRUE)))
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = delay ~ airlines, data = d, na.rm = TRUE)
#
# $airlines
#               diff        lwr       upr p adj
# BOS-ATL  3.9857565  3.8770998  4.094413     0
# CLT-ATL -2.4028827 -2.4989565 -2.306809     0
# DEN-ATL  0.9335241  0.8425861  1.024462     0
# DFW-ATL -0.7345976 -0.8102052 -0.658990     0
# CLT-BOS -6.3886392 -6.5139174 -6.263361     0
# DEN-BOS -3.0522324 -3.1736168 -2.930848     0
# DFW-BOS -4.7203541 -4.8307215 -4.609987     0
# DEN-CLT  3.3364067  3.2261431  3.446670     0
# DFW-CLT  1.6682851  1.5702807  1.766289     0
# DFW-DEN -1.6681217 -1.7610970 -1.575146     0

# %% [markdown]
# ##Time Series Analysis##

# %%
# %%R
# t1987=airports$V4[airports$V2 == 1987]
# t1988=airports$V4[airports$V2 == 1988]
# t1989=airports$V4[airports$V2 == 1989]
# t1990=airports$V4[airports$V2 == 1990]
# t1991=airports$V4[airports$V2 == 1991]
# t1992=airports$V4[airports$V2 == 1992]
# t1993=airports$V4[airports$V2 == 1993]
# t1994=airports$V4[airports$V2 == 1994]
# t1995=airports$V4[airports$V2 == 1995]
# t1996=airports$V4[airports$V2 == 1996]
# t1997=airports$V4[airports$V2 == 1997]
# t1998=airports$V4[airports$V2 == 1998]
# t1999=airports$V4[airports$V2 == 1999]
# t2000=airports$V4[airports$V2 == 2000]
# t2001=airports$V4[airports$V2 == 2001]
# t2002=airports$V4[airports$V2 == 2002]
# t2003=airports$V4[airports$V2 == 2003]
# t2004=airports$V4[airports$V2 == 2004]
# t2005=airports$V4[airports$V2 == 2005]
# t2006=airports$V4[airports$V2 == 2006]
# t2007=airports$V4[airports$V2 == 2007]
# t2008=airports$V4[airports$V2 == 2008]
# combined=c(t1987,t1988,t1989,t1990,t1991,t1992,t1993,t1994,t1995,t1996,t1997,t1998,t1999,t2000,t2001,t2002,t2003,t2004,t2005,t2006,t2007,t2008)
# timeseries <- ts(combined)
# plot.ts(timeseries)
# library("TTR")
# timeseriesSMA3 <- SMA(timeseries,n=10)
# plot.ts(timeseriesSMA3)
# Out:
# Loading required package: xts
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
# %%R
# expsmooth <- HoltWinters(timeseries, beta=FALSE, gamma=FALSE)
# expsmooth
# Out:
# Holt-Winters exponential smoothing without trend and without seasonal component.
#
# Call:
# HoltWinters(x = timeseries, beta = FALSE, gamma = FALSE)
#
# Smoothing parameters:
#  alpha: 0.03294331
#  beta : FALSE
#  gamma: FALSE
#
# Coefficients:
#       [,1]
# a 6.808911

# %%
# %%R
# expsmooth$fitted
# Out:
# Time Series:
# Start = 2
# End = 62777481
# Frequency = 1
#                  xhat        level
#        2 3.000000e+00 3.000000e+00
#        3 3.197660e+00 3.197660e+00
#        4 3.092318e+00 3.092318e+00
#        5 3.023390e+00 3.023390e+00
#        6 3.121450e+00 3.121450e+00
#        7 3.084506e+00 3.084506e+00
#        8 3.048778e+00 3.048778e+00
#        9 3.211888e+00 3.211888e+00
#       10 3.270794e+00 3.270794e+00
#       11 3.426590e+00 3.426590e+00
#       12 3.346650e+00 3.346650e+00
#       13 3.961153e+00 3.961153e+00
#       14 3.962433e+00 3.962433e+00
#       15 4.490764e+00 4.490764e+00
#       16 4.738143e+00 4.738143e+00
#       17 4.746769e+00 4.746769e+00
#       18 4.590395e+00 4.590395e+00
#       19 4.669775e+00 4.669775e+00
#       20 5.108917e+00 5.108917e+00
#       21 5.434762e+00 5.434762e+00
#       22 5.914589e+00 5.914589e+00
#       23 6.312723e+00 6.312723e+00
#       24 6.401251e+00 6.401251e+00
#       25 6.223315e+00 6.223315e+00
# ...

# %%
# %%R
# plot.ts(timeseries)
# plot(expsmooth)
